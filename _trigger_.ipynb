# %%
# %pip install -r requirements.txt

# %%
dbutils.library.restartPython()

# %%
# %run ./_paramgplayscrapper

# %%
# %run ./_envsettings

# %%
# %run ./scrappers/GoogleplayScrapperNotebook

# %%
# %run ./scrappers/load-data-bronze

# %%
# %run ./src/Keyword_Extraction_Code_Notebook

# %%
# %run ./src/Sentiment_Analysis_Code_Notebook

# %%
# %pip install openai

# %%
dbutils.library.restartPython()

# %%
# %run ./_paramgplayscrapper

# %%
# %run ./_envsettings

# %%
# %run ./src/Topic_Modelling_Code_Notebook

# %%
# %run ./src/load-data-silver
