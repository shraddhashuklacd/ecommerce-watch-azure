# %%
# %sql
CREATE CATALOG IF NOT EXISTS silver COMMENT 'Catalog for ADLS-based external data silver layer';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS silver.gplayscrapper COMMENT 'Schema for Google Play Scrapper';

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS silver.gplayscrapper.pentaloons_review_keyword_extraction
USING DELTA
LOCATION 'abfss://root@ecommerceadlsgen2.dfs.core.windows.net/datalake/silver/gplayscrapper/pentaloons_review_keyword_extraction/';

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS silver.gplayscrapper.pentaloons_review_sentiment_analyze
USING DELTA
LOCATION 'abfss://root@ecommerceadlsgen2.dfs.core.windows.net/datalake/silver/gplayscrapper/pentaloons_review_sentiment_analyze/';

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS silver.gplayscrapper.pentaloons_review_topic_modelling
USING DELTA
LOCATION 'abfss://root@ecommerceadlsgen2.dfs.core.windows.net/datalake/silver/gplayscrapper/pantaloons_reviews_topic_modelling_output/';
