# %%
# %sql
CREATE CATALOG IF NOT EXISTS bronze COMMENT 'Catalog for ADLS-based external data';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze.gplayscrapper COMMENT 'Schema for Google PLay Scrapper';

# %%
# %sql
CREATE EXTERNAL TABLE IF NOT EXISTS bronze.gplayscrapper.pentaloons
USING DELTA
LOCATION 'abfss://root@ecommerceadlsgen2.dfs.core.windows.net/datalake/bronze/gplayscrapper/pentaloons/';
